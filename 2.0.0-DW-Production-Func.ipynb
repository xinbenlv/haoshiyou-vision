# %% [markdown]
# ### HAOSHIYOU VISION
#
# * Split Long Wechat/Ins images into short images
# * Detect text from image
# * Transform image

# %% [markdown]
# #### Split long images

# %%
# load Module
from image import HaoShiYouImage

# Read Image
import glob
import random

input_path = 'data/raw/'
output_path = ''
img_list = glob.glob(input_path+'/*.jpg')

index = random.randint(0,len(img_list))
img = img_list[index]

# Split image
result = HaoShiYouImage.split(img)

# %% [markdown]
# #### Split results

# %%
# %matplotlib inline  

import matplotlib.pyplot as plt
from matplotlib import cm

for _img in result:
    
    plt.figure(figsize=(10,8))
    plt.imshow(_img,cmap=plt.cm.gray)
    plt.show()

# %%
string = 'abc.cde.png'

string.split('.',1)
# Out:
# ['abc', 'cde.png']
